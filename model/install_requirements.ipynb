# %% [markdown]
# Install: sudo apt update && sudo apt install -y portaudio19-dev python3-dev build-essential

# %% [markdown]
# # Gebruik dit notebook om alle Python-bibliotheken te installeren die nodig zijn voor deze cursus. Je kunt deze code uitvoeren in een Jupyter Notebook.

# %%
# !pip3 install ipykernel

# %%
# !pip install matplotlib pandas numpy jupyter scipy tqdm

# %%
# !pip install pyaudio

# %%
# !pip install jupyter_contrib_nbextensions jupyter_nbextensions_configurator

# %%
# !pip install --no-cache-dir tensorflow

# %%
#!export TF_CPP_MIN_LOG_LEVEL=2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
